# %% [markdown]
# <a href="https://colab.research.google.com/github/Ju5t1n-Wang/SJSU_EE104/blob/main/Lab8_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras.datasets import cifar10
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from keras import regularizers
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.optimizers import SGD

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(32,
                                  32,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
weight_decay = 1e-4

model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3), kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.2))

model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.4))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.compile('adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 17s 10ms/step - loss: 0.9225 - accuracy: 0.7180 - val_loss: 0.8752 - val_accuracy: 0.7387
# Epoch 2/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8849 - accuracy: 0.7425 - val_loss: 0.9413 - val_accuracy: 0.7221
# Epoch 3/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8596 - accuracy: 0.7546 - val_loss: 0.8471 - val_accuracy: 0.7591
# Epoch 4/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8404 - accuracy: 0.7645 - val_loss: 0.8505 - val_accuracy: 0.7612
# Epoch 5/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8135 - accuracy: 0.7778 - val_loss: 0.8174 - val_accuracy: 0.7772
# Epoch 6/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8084 - accuracy: 0.7814 - val_loss: 0.7804 - val_accuracy: 0.7945
# Epoch 7/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7977 - accuracy: 0.7880 - val_loss: 0.9499 - val_accuracy: 0.7420
# Epoch 8/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7937 - accuracy: 0.7905 - val_loss: 0.7756 - val_accuracy: 0.7983
# Epoch 9/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7803 - accuracy: 0.7977 - val_loss: 0.7596 - val_accuracy: 0.8058
# Epoch 10/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7770 - accuracy: 0.8004 - val_loss: 0.7836 - val_accuracy: 0.7998
# Epoch 11/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7657 - accuracy: 0.8058 - val_loss: 0.7831 - val_accuracy: 0.8021
# Epoch 12/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7623 - accuracy: 0.8095 - val_loss: 0.7665 - val_accuracy: 0.8093
# Epoch 13/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7564 - accuracy: 0.8114 - val_loss: 0.7699 - val_accuracy: 0.8112
# Epoch 14/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7526 - accuracy: 0.8146 - val_loss: 0.7950 - val_accuracy: 0.7990
# Epoch 15/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7417 - accuracy: 0.8185 - val_loss: 0.7903 - val_accuracy: 0.8071
# Epoch 16/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7375 - accuracy: 0.8191 - val_loss: 0.7865 - val_accuracy: 0.8106
# Epoch 17/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7367 - accuracy: 0.8224 - val_loss: 0.7780 - val_accuracy: 0.8091
# Epoch 18/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7307 - accuracy: 0.8247 - val_loss: 0.7977 - val_accuracy: 0.8042
# Epoch 19/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7340 - accuracy: 0.8240 - val_loss: 0.7477 - val_accuracy: 0.8240
# Epoch 20/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7340 - accuracy: 0.8237 - val_loss: 0.8149 - val_accuracy: 0.8030

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(20)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.8149 - accuracy: 0.8030 - 979ms/epoch - 3ms/step
